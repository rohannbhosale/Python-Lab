# %%
print("Hello")
# Out:
# Hello

# %%
# !pip install flask
# Out:
# ...
#
#    ---------------------------------------- 0/5 [werkzeug]
#    ---------------------------------------- 0/5 [werkzeug]
#    ---------------------------------------- 0/5 [werkzeug]
#    ---------------- ----------------------- 2/5 [click]
#    ------------------------ --------------- 3/5 [blinker]
#    -------------------------------- ------- 4/5 [flask]
#    ---------------------------------------- 5/5 [flask]
#
# ...
